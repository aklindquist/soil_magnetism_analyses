# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
X = pd.read_csv("C:\\Users\\alindqu1\\Desktop\\SoilStudy\\StOB_Xdata.csv") #input file name here
X.head(4)
# Out:
#    d1989     p1989  d1993     p1993  d2004     p2004
# 0   10.5  0.806556    7.0  0.853914    6.0  0.795338
# 1   13.0  0.776801   10.0  0.837779    9.0  0.841678
# 2   15.5  0.799039   12.5  0.925685   12.0  0.790930
# 3   18.0  0.772337   15.0  0.851370   15.0  0.868607

# %%
#plt.axvline(x=0,color='#999999')
#plt.axhline(y=0,color='#999999')

#plt.figaspect(0.8)
plt.figure(figsize=(6.0,8.0))
plt.plot(X.p1989,X.d1989,color='#990066')
plt.plot(X.p1993,X.d1993,color='#999999')
plt.plot(X.p2004,X.d2004,color='#003333')
plt.ylim(85,0)
plt.xlabel('susceptibility (normalized)')
plt.ylabel('depth (cm)')
plt.savefig("C:\\Users\\alindqu1\\Desktop\\SoilStudy\\fig.jpg")


#plt.axes.set_axes('equal')
#plt.axis(equal)
#plt.figaspect(6)
#plt.set_aspect(1)
#print(X.snum)
#p1989.invert_yaxis(X.snum)
